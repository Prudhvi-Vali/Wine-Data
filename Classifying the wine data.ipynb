# %%
# The dataset is acquired from the UCI Machine learning repository. 
# Source: Institute of Pharmaceutical and Food Analysis and Technologies
# The details are the findings of a chemical study of three separate cultivars of wine grown in the same region of Italy. The amount of 13 constituents present in each of the three types of wines was calculated via the study.
# It consists of a total of 178 instances and is classified into three classes.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wine_df = pd.read_csv('C:/Users/syd/Desktop/Machine Learning/DMP/DataMining Project/Wine.csv')
wine_df.head()
# Out:
#    name  alcohol  malicAcid   ash  ashalcalinity  magnesium  total Phenols  \
# 0     1    13.20       1.78  2.14           11.2        100           2.65
# 1     1    13.16       2.36  2.67           18.6        101           2.80
# 2     1    14.37       1.95  2.50           16.8        113           3.85
# 3     1    13.24       2.59  2.87           21.0        118           2.80
# 4     1    14.20       1.76  2.45           15.2        112           3.27
#
#    flavanoids  non Flavanoid Phenols  proanthocyanins  colorIntensity   hue  \
# 0        2.76                   0.26             1.28            4.38  1.05
# 1        3.24                   0.30             2.81            5.68  1.03
# 2        3.49                   0.24             2.18            7.80  0.86
# 3        2.69                   0.39             1.82            4.32  1.04
# 4        3.39                   0.34             1.97            6.75  1.05
#
#    od280_od315  proline
# 0         3.40     1050
# ...

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   177 non-null    int64
#  1   alcohol                177 non-null    float64
#  2   malicAcid              177 non-null    float64
#  3   ash                    177 non-null    float64
#  4   ashalcalinity          177 non-null    float64
#  5   magnesium              177 non-null    int64
#  6   total Phenols          177 non-null    float64
#  7   flavanoids             177 non-null    float64
#  8   non Flavanoid Phenols  177 non-null    float64
#  9   proanthocyanins        177 non-null    float64
#  10  colorIntensity         177 non-null    float64
#  11  hue                    177 non-null    float64
#  12  od280_od315            177 non-null    float64
#  13  proline                177 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %%
wine_col = wine_df.columns
print(wine_col)
# Out:
# Index(['name', 'alcohol', 'malicAcid', 'ash', 'ashalcalinity', 'magnesium',
#        'total Phenols', 'flavanoids', 'non Flavanoid Phenols',
#        'proanthocyanins', 'colorIntensity', 'hue', 'od280_od315', 'proline'],
#       dtype='object')

# %%
# Missing values in the dataset.

# %%
wine_df.isna().sum()
# Out:
# name                     0
# alcohol                  0
# malicAcid                0
# ash                      0
# ashalcalinity            0
# magnesium                0
# total Phenols            0
# flavanoids               0
# non Flavanoid Phenols    0
# proanthocyanins          0
# colorIntensity           0
# hue                      0
# od280_od315              0
# proline                  0
# dtype: int64

# %%
x =  wine_df.iloc[:,1:]
y = wine_df.iloc[:,:1]
y_arr = pd.DataFrame(y).to_numpy()
#print(y_arr)

# %%
# The target variable is "name," which ranges from 1 to 3.
#The data is equally distributed with a considerable difference.
#We can observe that the wine under class - 2 has a higher count than the other class

# %%
wine_df['name'].value_counts()
# Out:
# 2    71
# 1    58
# 3    48
# Name: name, dtype: int64

# %%
sns.countplot(wine_df['name'])
plt.show()
# Out:
# C:\Users\syd\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# We can observe from the graph that the majority of the alcohol values are concentrated between the values 11-15

# %%
sns.countplot(wine_df['alcohol'])
plt.show()
# Out:
# C:\Users\syd\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.distplot(wine_df['alcohol'])
# Out:
# C:\Users\syd\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %%
# We can observe from the graph that the majority of the proline values are concentrated between the values 250-900

# %%
sns.countplot(wine_df['proline'])
plt.show()
sns.distplot(wine_df['proline'])
plt.show()
# Out:
# C:\Users\syd\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\syd\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# We can observe from the graph that the majority of the colorIntensity values are concentrated between the
#values 2.0-7.5 ad are decreasing.

# %%
sns.distplot(wine_df['colorIntensity'])
plt.show()
# Out:
# C:\Users\syd\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(wine_df['colorIntensity'])
plt.show()
# Out:
# C:\Users\syd\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# We can observe from the graph that the majority of the flavanoids values are concentrated between the
#values 0.5-4.0 ad are decreasing.

# %%
sns.distplot(wine_df['flavanoids'])
plt.show()
# Out:
# C:\Users\syd\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(wine_df['flavanoids'])
plt.show()
# Out:
# C:\Users\syd\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# We can observe from the graph that the majority of the Magnesium values are concentrated between the
#values 70-120 ad are decreasing.

# %%
sns.distplot(wine_df['magnesium'])
plt.show()
# Out:
# C:\Users\syd\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(wine_df['magnesium'])
plt.show()
# Out:
# C:\Users\syd\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Pair plots show all single-variable distributions and correlations between two variables. 
# Pair plots are an excellent method to identify trends for analysis.

# %%
sns.pairplot(wine_df, hue='name')

# %%
wineSub = wine_df[['name','proline','alcohol','magnesium','flavanoids','colorIntensity']]

# %%
sns.pairplot(wineSub,hue='name')

# %%
# Correlation between the features. The correlation matrix between variables gives the 
# number of the features that are either dependent or independent on each other and the target variable.

# %%
#pd.options.display.float_format = '{:,.3f}'.format--to display 3 digits after the decimal
round(wine_df.corr(),3)
# Out:
#                         name  alcohol  malicAcid    ash  ashalcalinity  \
# name                   1.000   -0.321      0.436 -0.048          0.514
# alcohol               -0.321    1.000      0.100  0.211         -0.303
# malicAcid              0.436    0.100      1.000  0.165          0.286
# ash                   -0.048    0.211      0.165  1.000          0.447
# ashalcalinity          0.514   -0.303      0.286  0.447          1.000
# magnesium             -0.199    0.259     -0.049  0.287         -0.072
# total Phenols         -0.718    0.285     -0.334  0.128         -0.318
# flavanoids            -0.846    0.230     -0.409  0.114         -0.347
# non Flavanoid Phenols  0.487   -0.151      0.292  0.187          0.359
# proanthocyanins       -0.495    0.128     -0.218  0.008         -0.191
# colorIntensity         0.269    0.548      0.250  0.259          0.020
# hue                   -0.618   -0.075     -0.561 -0.075         -0.273
# ...

# %%
# sns.heatmap?

# %%
plt.figure(figsize=(20,15))
corr_wine = wine_df[wine_df.columns].corr()
sns.heatmap(corr_wine, cmap="Blues", annot = True)
# Out:
# <AxesSubplot:>

# %%
# Correlation	Feature
# Strong positive 	Flavinoids and od280_od315(0.79)
#                   Total Phenols and od280_od315(0.70)
#                   Flavinoids and Total Phenols(0.86)
# Moderate positive 	Flavinoids and proanthocyanins (0.67), 
#                         Proline and Alcohol(0.64), 
#                        Alcohol and colorIntensity (0.55)
#Strong Negitive  	      Malic acid and Magnesium(-0.049),
#                         Ashalcalinity and Magnesium (-0.072),
#                         Alcohol and Hue (-0.075
#
#

# %%
# Generally, correlated features do not improve models (but it always depends on the problem at hand).
# However, they affect specific models in different ways and to varying extents.
# We have written a function that traverses through the correlation matrix 
# and stores the features whose correlation crosses the threshold.

# %%
def correlation_high(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = wine_df.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if corr_matrix.iloc[i, j] > threshold and (corr_matrix.columns[j] not in col_corr): # we are interested in absolute coeff value, check for non abs values too
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
# After thorough research, we have finalized to set the threshold to be 90%.
#Surprisingly we found the none of the values have a higher correlation between each other.

# %%
corr_features = correlation_high(wine_df, 0.90)
len(set(corr_features))
# Out:
# 0

# %%
corr_features
# Out:
# set()

# %%
# The quantitative measurement of clusters across various values is referred to as cluster mapping. 
# Cluster categories are represented as groups that are connected by localized spill-overs and linkages.

# %%
# We can observe from the figure that Malic acid,ashalcalinity,non Flavanoids Phenols fall under a first cluster.
#rest fall under the different cluster.

# %%
#plt.figure(figsize=(20,15)
sns.clustermap(wine_df.corr(), figsize=(15,12), cmap="BuGn",annot=True)

# %%
# The process of filtering and screening the input variables to reduce the size 
# and computation cost involved in developing a good prediction model is considered as feature importance.

# %%
# We have used the computed correlation function, L1,l2 regularization, 
# ExtraTreesClassifier, selectKbest using the chi2 score and found promising results while using the correlation function 
#, selectKBest and ExtraTreesClassifier for the dataset we have considered.

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
data = wine_df.copy()
X_data = data.iloc[:,1:]  #independent columns
y_data = data.iloc[:,0]    #target column i.e price range
#apply SelectKBest class to extract features in descending order
orderfeatures = SelectKBest(score_func=chi2, k =13)
fit = orderfeatures.fit(X_data,y_data)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X_data.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Features','CHI-Score']  #naming the dataframe columns
print(featureScores.nlargest(13,'CHI-Score'))  #print 13 best features
# Out:
#                  Features     CHI-Score
# 12                proline  16446.895876
# 9          colorIntensity    109.022694
# 6              flavanoids     62.991596
# 4               magnesium     41.953227
# 3           ashalcalinity     28.676542
# 1               malicAcid     27.896849
# 11            od280_od315     23.022222
# 5           total Phenols     15.531400
# 8         proanthocyanins      9.179720
# 0                 alcohol      5.349870
# 10                    hue      5.178420
# 7   non Flavanoid Phenols      1.794852
# 2                     ash      0.742062

# %%
from sklearn.ensemble import ExtraTreesClassifier

model = ExtraTreesClassifier()
model.fit(X_data,y_data)
print("The values for the features are :\n",model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X_data.columns)
feat_importances.nlargest(13).plot(kind = 'bar', color = 'Black')
plt.show()
# Out:
# The values for the features are :
#  [0.12332207 0.047424   0.0297183  0.03427673 0.03513441 0.06827381
#  0.15513866 0.03073342 0.02829764 0.10527083 0.06744783 0.11790542
#  0.15705688]

# %%
#we can remove the ash as it has the least score

# %%
x.drop(columns = ['ash'], axis = 1)
# Out:
#      alcohol  malicAcid  ashalcalinity  magnesium  total Phenols  flavanoids  \
# 0      13.20       1.78           11.2        100           2.65        2.76
# 1      13.16       2.36           18.6        101           2.80        3.24
# 2      14.37       1.95           16.8        113           3.85        3.49
# 3      13.24       2.59           21.0        118           2.80        2.69
# 4      14.20       1.76           15.2        112           3.27        3.39
# ..       ...        ...            ...        ...            ...         ...
# 172    13.71       5.65           20.5         95           1.68        0.61
# 173    13.40       3.91           23.0        102           1.80        0.75
# 174    13.27       4.28           20.0        120           1.59        0.69
# 175    13.17       2.59           20.0        120           1.65        0.68
# 176    14.13       4.10           24.5         96           2.05        0.76
#
# ...

# %%
from sklearn.preprocessing import StandardScaler, Normalizer
ss = StandardScaler()
x_ss = ss.fit_transform(x)
x_ss_df = pd.DataFrame(x_ss)

print(x_ss_df.head())
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.255824 -0.501624 -0.824485 -2.500110  0.029180  0.572666  0.739636
# 1  0.206229  0.018020  1.107690 -0.275639  0.099932  0.812784  1.221645
# 2  1.706501 -0.349315  0.487935 -0.816726  0.948953  2.493609  1.472691
# 3  0.305420  0.224086  1.836812  0.445811  1.302712  0.812784  0.669343
# 4  1.495719 -0.519543  0.305655 -1.297693  0.878201  1.565153  1.372273
#
#          7         8         9         10        11        12
# 0 -0.823139 -0.538575 -0.291130  0.407100  1.131698  0.971052
# 1 -0.501337  2.145975  0.269729  0.319567  0.804579  1.400998
# 2 -0.984039  1.040572  1.184362 -0.424458  1.202811  2.340509
# 3  0.222716  0.408913 -0.317016  0.363334  0.463238 -0.032154
# 4 -0.179536  0.672104  0.731360  0.407100  0.349457  2.244965

# %%
norm = Normalizer()

x_ss_n = norm.fit_transform(x_ss)

#print(x_table)

x_ss_n_df = pd.DataFrame(x_ss_n)

#print(x_ss_n)
print(x_ss_n_df.head())
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.075226 -0.147504 -0.242443 -0.735166  0.008581  0.168394  0.217493
# 1  0.061760  0.005396  0.331721 -0.082546  0.029927  0.243405  0.365847
# 2  0.349906 -0.071624  0.100048 -0.167464  0.194576  0.511297  0.301965
# 3  0.113928  0.083589  0.685170  0.166297  0.485939  0.303185  0.249679
# 4  0.377063 -0.130974  0.077054 -0.327142  0.221390  0.394567  0.345943
#
#          7         8         9         10        11        12
# 0 -0.242047 -0.158370 -0.085608  0.119709  0.332780  0.285541
# 1 -0.150136  0.642657  0.080776  0.095701  0.240948  0.419558
# 2 -0.201770  0.213362  0.242845 -0.087032  0.246628  0.479904
# 3  0.083078  0.152533 -0.118254  0.135531  0.172797 -0.011994
# 4 -0.045260  0.169434  0.184372  0.102628  0.088096  0.565945

# %%
# Spliting the dataset to traget and test data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_ss_n, y_arr, test_size = 0.2, random_state = 0)
#print(y_train)

# %%
#SVM with the linear kernel

# %%
from sklearn.svm import SVC

svc_lnr = SVC(kernel = 'linear', random_state = 1, probability=True)

svc_lnr.fit(x_train, y_train)

svc_lnr_prdt = svc_lnr.predict(x_test)

prdt_proba_svc_lnr = svc_lnr.predict_proba(x_test)

#svc_lnr_prdt_df = pd.DataFrame(svc_lnr_prdt)
# Out:
# C:\Users\syd\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
# True Positive (TP): Predicted positive for an actual positive value.
# True Negative (TN): Predicted negative for an actual negative value.
# False Positive (FN): Predicted positive for an actual negative value.
# False Negative (FN): Predicted negative for an actual positive value.

# %%
# Precision: It’s the ratio between the correct positives to the total positive predictions.
# Precision=TP/(TP+FP)
# Recall: It’s the ratio between the correct positives and samples that should be positive. 
# Recall=  TP/(TP+FN)
# F-scores: Measures the model's accuracy on the datasets. It is the harmonic mean between precision and recall.
# F1-scores=(2*precision*recall)/(precision+recall)

# %%
# Accuracy: Accuracy is the performance metric of the machine learning model and is defines as the percentage of 
#correctness in the predicted value of the test data. 
#In other words it’s the ratio between the correct predictions to total number of predictions.  

# Accuracy=(TP+TN)/(TP+FP+TN+FN)

# %%
from sklearn.metrics import accuracy_score

svc_lnr_acc = accuracy_score(svc_lnr_prdt, y_test)

print('The accuracy of the SVM linear kernel is {}'.format(round(svc_lnr_acc, 6)))

svc_lnr_acc_train = svc_lnr.score(x_train, y_train)

print('The accuracy of the SVM linear kernel for training data is {}'.format(round(svc_lnr_acc_train, 6)))
# Out:
# The accuracy of the SVM linear kernel is 0.972222
# The accuracy of the SVM linear kernel for training data is 0.985816

# %%
Accuracy_score_list = []
Accuracy_score_list.append(svc_lnr_acc)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report

# %%
print('Micro Precision for SVC linear kernel : {:.4f}'.format(precision_score(y_test, svc_lnr_prdt, average='micro')))

print('Micro Recall for SVC linear kernel : {:.4f}'.format(recall_score(y_test, svc_lnr_prdt, average='micro')))

print('Micro F1-score SVC linear kernel : {:.4f}\n'.format(f1_score(y_test, svc_lnr_prdt, average='micro')))

print('Macro Precision SVC linear kernel : {:.4f}'.format(precision_score(y_test, svc_lnr_prdt, average='macro')))

print('Macro Recall for SVC linear kernel : {:.4f}'.format(recall_score(y_test, svc_lnr_prdt, average='macro')))

print('Macro F1-score for SVC linear kernel : {:.4f}\n'.format(f1_score(y_test, svc_lnr_prdt, average='macro')))

print('Weighted Precision for SVC linear kernel : {:.4f}'.format(precision_score(y_test, svc_lnr_prdt, average='weighted')))

print('Weighted Recall for SVC linear kernel : {:.4f}'.format(recall_score(y_test, svc_lnr_prdt, average='weighted')))

print('Weighted F1-score for SVC linear kernel : {:.4f}'.format(f1_score(y_test, svc_lnr_prdt, average='weighted')))
# Out:
# Micro Precision for SVC linear kernel : 0.9722
# Micro Recall for SVC linear kernel : 0.9722
# Micro F1-score SVC linear kernel : 0.9722
#
# Macro Precision SVC linear kernel : 0.9792
# Macro Recall for SVC linear kernel : 0.9524
# Macro F1-score for SVC linear kernel : 0.9636
#
# Weighted Precision for SVC linear kernel : 0.9740
# Weighted Recall for SVC linear kernel : 0.9722
# Weighted F1-score for SVC linear kernel : 0.9716

# %%
print("classification report for Linear SVM Kernel :\n", classification_report(y_test, svc_lnr_prdt, target_names=['1', '2', '3']))
# Out:
# classification report for Linear SVM Kernel :
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        14
#            2       0.94      1.00      0.97        15
#            3       1.00      0.86      0.92         7
#
#     accuracy                           0.97        36
#    macro avg       0.98      0.95      0.96        36
# weighted avg       0.97      0.97      0.97        36

# %%
#A confusion matrix is a table that shows how well a classification model (or "classifier")
#does on a collection of test data on which the actual values are known.

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

svc_lnr_cm = confusion_matrix(svc_lnr_prdt, y_test)

print('The Confusion matrix of the SVM linear kernel is \n{}'.format(svc_lnr_cm))

#plt.title('Confusion Matrix for Linear SVM kernel for multi-class data')
class_names = wine_df['name'].unique()
disp_svc_lnr_cm = ConfusionMatrixDisplay(confusion_matrix=svc_lnr_cm, display_labels=class_names)
disp = disp_svc_lnr_cm.plot()
plt.show()
# Out:
# The Confusion matrix of the SVM linear kernel is
# [[14  0  0]
#  [ 0 15  1]
#  [ 0  0  6]]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
#LogisticRegression
log_reg =LogisticRegression()

log_reg.fit(x_train,y_train)

log_reg_prdt = log_reg.predict(x_test)

log_reg_acc = accuracy_score(log_reg_prdt, y_test)

log_reg_acc_train = log_reg.score(x_train, y_train)

#log_reg_acc_test = log_reg.score(x_test, y_test)

prdt_proba_log_reg = log_reg.predict_proba(x_test)


print('Accuracy of Logistic regression classifier : {}'.format(round(log_reg_acc, 6)))
print('Accuracy of Logistic regression classifier on train set: {:,.6f}'.format(log_reg_acc_train))
#print('Accuracy of Logistic regression classifier on train set: {:,.6f}'.format(log_reg_acc_test))

Accuracy_score_list.append(log_reg_acc)
# Out:
# Accuracy of Logistic regression classifier : 1.0
# Accuracy of Logistic regression classifier on train set: 0.992908
# C:\Users\syd\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print('Micro Precision for Logistic regression classifier : {:.4f}'.format(precision_score(y_test, log_reg_prdt, average='micro')))

print('Micro Recall for Logistic regression classifier : {:.4f}'.format(recall_score(y_test, log_reg_prdt, average='micro')))

print('Micro F1-score Logistic regression classifier : {:.4f}\n'.format(f1_score(y_test, log_reg_prdt, average='micro')))
# Out:
# Micro Precision for Logistic regression classifier : 1.0000
# Micro Recall for Logistic regression classifier : 1.0000
# Micro F1-score Logistic regression classifier : 1.0000

# %%
print("classification report for Logistic regression classifier :\n", classification_report(y_test, log_reg_prdt, target_names=['1', '2', '3']))
# Out:
# classification report for Logistic regression classifier :
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        14
#            2       1.00      1.00      1.00        15
#            3       1.00      1.00      1.00         7
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %%
log_reg_cm = confusion_matrix(log_reg_prdt, y_test)

print('The Confusion matrix of the Logistic regression classifier is \n{}'.format(log_reg_cm))

#plt.title('Confusion Matrix for Linear SVM kernel for multi-class data')
class_names = wine_df['name'].unique()
disp_log_reg_cm = ConfusionMatrixDisplay(confusion_matrix=log_reg_cm, display_labels=class_names)
disp = disp_log_reg_cm.plot()
plt.show()
# Out:
# The Confusion matrix of the Logistic regression classifier is
# [[14  0  0]
#  [ 0 15  0]
#  [ 0  0  7]]

# %%
gnb = GaussianNB()

gnb.fit(x_train, y_train)

gnb_prdt = gnb.predict(x_test)

gnb_prdt_acc = accuracy_score(gnb_prdt, y_test)

gnb_acc_train = gnb.score(x_train,y_train)

prdt_proba_gnb = gnb.predict_proba(x_test)


print('Accuracy of Gaussian Navie Bayes classifier : {}'.format(round(gnb_prdt_acc, 6)))
print('Accuracy of Gaussian Navie Bayes classifier on train set: {:,.6f}'.format(gnb_acc_train))
Accuracy_score_list.append(gnb_prdt_acc)
# Out:
# Accuracy of Gaussian Navie Bayes classifier : 1.0
# Accuracy of Gaussian Navie Bayes classifier on train set: 0.978723
# C:\Users\syd\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print('Micro Precision for Gaussian Navie Bayes classifier : {:.4f}'.format(precision_score(y_test, gnb_prdt, average='micro')))

print('Micro Recall for Gaussian Navie Bayes classifier : {:.4f}'.format(recall_score(y_test, gnb_prdt, average='micro')))

print('Micro F1-score Gaussian Navie Bayes classifier : {:.4f}\n'.format(f1_score(y_test, gnb_prdt, average='micro')))
# Out:
# Micro Precision for Gaussian Navie Bayes classifier : 1.0000
# Micro Recall for Gaussian Navie Bayes classifier : 1.0000
# Micro F1-score Gaussian Navie Bayes classifier : 1.0000

# %%
print("classification report for Gaussian Navie Bayes classifier :\n", classification_report(y_test, gnb_prdt, target_names=['1', '2', '3']))
# Out:
# classification report for Gaussian Navie Bayes classifier :
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        14
#            2       1.00      1.00      1.00        15
#            3       1.00      1.00      1.00         7
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %%
gnb_cm = confusion_matrix(gnb_prdt, y_test)

print('The Confusion matrix of the Gaussian Navie Bayes classifier is \n{}'.format(gnb_cm))

#plt.title('Confusion Matrix for Linear SVM kernel for multi-class data')
class_names = wine_df['name'].unique()
disp_gnb_cm = ConfusionMatrixDisplay(confusion_matrix=gnb_cm, display_labels=class_names)
disp = disp_gnb_cm.plot()
plt.show()
# Out:
# The Confusion matrix of the Gaussian Navie Bayes classifier is
# [[14  0  0]
#  [ 0 15  0]
#  [ 0  0  7]]

# %%
rfc = RandomForestClassifier()

rfc.fit(x_train,y_train)

rfc_prdt = rfc.predict(x_test)

rfc_prdt_acc = accuracy_score(rfc_prdt, y_test)

rfc_acc_train = rfc.score(x_train,y_train)

prdt_proba_rfc = rfc.predict_proba(x_test)


print('Accuracy of Random Forest classifier : {}'.format(round(rfc_prdt_acc, 6)))
print('Accuracy of Random Forest classifier on train set: {:,.6f}'.format(rfc_acc_train))
Accuracy_score_list.append(rfc_prdt_acc)
# Out:
# C:\Users\syd\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# Accuracy of Random Forest classifier : 1.0
# Accuracy of Random Forest classifier on train set: 1.000000

# %%
print('Micro Precision for Random Forest classifier : {:.4f}'.format(precision_score(y_test, rfc_prdt, average='micro')))

print('Micro Recall for Random Forest classifier : {:.4f}'.format(recall_score(y_test, rfc_prdt, average='micro')))

print('Micro F1-score Random Forest classifier : {:.4f}\n'.format(f1_score(y_test, rfc_prdt, average='micro')))
# Out:
# Micro Precision for Random Forest classifier : 1.0000
# Micro Recall for Random Forest classifier : 1.0000
# Micro F1-score Random Forest classifier : 1.0000

# %%
print("classification report for Random Forest classifier :\n", classification_report(y_test, rfc_prdt, target_names=['1', '2', '3']))
# Out:
# classification report for Random Forest classifier :
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        14
#            2       1.00      1.00      1.00        15
#            3       1.00      1.00      1.00         7
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %%
rfc_cm = confusion_matrix(rfc_prdt, y_test)

print('The Confusion matrix of the Random Forest classifier is \n{}'.format(rfc_cm))

#plt.title('Confusion Matrix for Linear SVM kernel for multi-class data')
class_names = wine_df['name'].unique()
disp_rfc_cm = ConfusionMatrixDisplay(confusion_matrix=rfc_cm, display_labels=class_names)
disp = disp_rfc_cm.plot()
plt.show()
# Out:
# The Confusion matrix of the Random Forest classifier is
# [[14  0  0]
#  [ 0 15  0]
#  [ 0  0  7]]

# %%
gbc = GradientBoostingClassifier()

gbc.fit(x_train,y_train)

gbc_prdt = gbc.predict(x_test)

gbc_prdt_acc = accuracy_score(gbc_prdt, y_test)

gnb_acc_train = gnb.score(x_train, y_train)

prdt_proba_gbc = gbc.predict_proba(x_test)

print('Accuracy of Gradient Boosting classifier : {}'.format(round(gbc_prdt_acc, 6)))
print('Accuracy of Gradient Boosting classifier on train set: {:,.6f}'.format(gnb_acc_train))
Accuracy_score_list.append(gbc_prdt_acc)
# Out:
# C:\Users\syd\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Accuracy of Gradient Boosting classifier : 1.0
# Accuracy of Gradient Boosting classifier on train set: 0.978723

# %%
print('Micro Precision for Gradient Boosting classifier : {:.4f}'.format(precision_score(y_test, gbc_prdt, average='micro')))

print('Micro Recall for Gradient Boosting classifier : {:.4f}'.format(recall_score(y_test, gbc_prdt, average='micro')))

print('Micro F1-score Gradient Boosting classifier : {:.4f}\n'.format(f1_score(y_test, gbc_prdt, average='micro')))
# Out:
# Micro Precision for Gradient Boosting classifier : 1.0000
# Micro Recall for Gradient Boosting classifier : 1.0000
# Micro F1-score Gradient Boosting classifier : 1.0000

# %%
print("classification report for Gradient Boosting classifier :\n", classification_report(y_test, gbc_prdt, target_names=['1', '2', '3']))
# Out:
# classification report for Gradient Boosting classifier :
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        14
#            2       1.00      1.00      1.00        15
#            3       1.00      1.00      1.00         7
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %%
gbc_cm = confusion_matrix(gbc_prdt, y_test)

print('The Confusion matrix of the Gradient Boosting classifier is \n{}'.format(gbc_cm))

#plt.title('Confusion Matrix for Linear SVM kernel for multi-class data')
class_names = wine_df['name'].unique()
disp_gbc_cm = ConfusionMatrixDisplay(confusion_matrix=gbc_cm, display_labels=class_names)
disp = disp_gbc_cm.plot()
plt.show()
# Out:
# The Confusion matrix of the Gradient Boosting classifier is
# [[14  0  0]
#  [ 0 15  0]
#  [ 0  0  7]]

# %%
print(len(Accuracy_score_list))
print(Accuracy_score_list)
# Out:
# 5
# [0.9722222222222222, 1.0, 1.0, 1.0, 1.0]

# %%
model_names = ['SVM Linear Kernel', 'Logistic regression','Navie Bayes', 'RandomForest', 'Gradient Boosting classifier ']
acc_dict = {}
acc_dict={'Modelling Algo':model_names,'Accuracy':Accuracy_score_list}
acc_dict
# Out:
# {'Modelling Algo': ['SVM Linear Kernel',
#   'Logistic regression',
#   'Navie Bayes',
#   'RandomForest',
#   'Gradient Boosting classifier '],
#  'Accuracy': [0.9722222222222222, 1.0, 1.0, 1.0, 1.0]}

# %%
acc_frame=pd.DataFrame(acc_dict)
acc_frame
# Out:
#                   Modelling Algo  Accuracy
# 0              SVM Linear Kernel  0.972222
# 1            Logistic regression  1.000000
# 2                    Navie Bayes  1.000000
# 3                   RandomForest  1.000000
# 4  Gradient Boosting classifier   1.000000

# %%
# We have found that Logistic Regression, Navie Bayes, Random Forrest and Gradient Boosting classifier have the best
#performance and the least performance is observed in The Support Vector Machine with Linear Kernel suggesting that
#the data is not linear.

# %%
sns.barplot(y='Modelling Algo',x='Accuracy',data=acc_frame)
# Out:
# <AxesSubplot:xlabel='Accuracy', ylabel='Modelling Algo'>

# %%
sns.factorplot(x='Modelling Algo',y='Accuracy',data=acc_frame,kind='point',size=4,aspect=3.5)
# Out:
# C:\Users\syd\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\syd\anaconda3\lib\site-packages\seaborn\categorical.py:3720: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import precision_recall_curve
import scikitplot as skplt

# %%
# Area under ROC curve (AUC): Measures the two-dimensional area under the ROC curve and the value ranges from 0 to1. 
# AUC is a metric that averages the overall classification thresholds performance. 
# The likelihood that the model scores a random positive example higher than a random negative example is one way to view AUC.
# AUC is classification-threshold-invariant-
# It assesses the accuracy of the model's predictions regardless of the classification threshold used.
# AUC is scale-invariant- Rather than measuring absolute values, it assesses how well predictions are ranked.

# %%
# ROC stands for receiver operating characteristic curve. It graphs the performance of the model at all the classification thresholds.
# The two parameters involved are
# True Positive Rate is the recall.
# Recall→True Positive Rate =  TP/(TP+FN)
# False Positive Rate FPR is a count of incorrect positive results that occur among all negative samples during the test.
# False Positive Rate(FPR)=  FP/(FP+TN)

# %%
skplt.metrics.plot_roc(y_test, prdt_proba_svc_lnr, plot_micro=False)
plt.title("ROC Curve for the Support Vector Machine Linear Kernel")
plt.show()

# %%
skplt.metrics.plot_roc(y_test, prdt_proba_log_reg, plot_micro=False)
plt.title("ROC Curve for the Logistic Regression")
plt.show()

# %%
skplt.metrics.plot_roc(y_test, prdt_proba_gnb, plot_micro=False)
plt.title("ROC Curve for the Navie Bayes Algorithm")
plt.show()

# %%
skplt.metrics.plot_roc(y_test, prdt_proba_rfc, plot_micro=False)
plt.title("ROC Curve for the Random Forest classifier")
plt.show()

# %%
skplt.metrics.plot_roc(y_test, prdt_proba_gbc, plot_micro=False)
plt.title("ROC Curve for the Gradient Boosting Classifier")
plt.show()
